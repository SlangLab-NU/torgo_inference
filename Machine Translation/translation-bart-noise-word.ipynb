# %%
# !pip install datasets
# !pip install transformers==4.28.0
# !pip install accelerate
# !pip install jiwer
# !pip install huggingface_hub
# Out:
# ...
#   Using cached transformers-4.28.0-py3-none-any.whl (7.0 MB)
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.26.1
#     Uninstalling transformers-4.26.1:
#       Successfully uninstalled transformers-4.26.1
# ...

# %%
import torch
from transformers import BartTokenizerFast, BartForConditionalGeneration, Seq2SeqTrainingArguments, Seq2SeqTrainer
from datasets import load_dataset
from sklearn.model_selection import train_test_split
from jiwer import wer
from huggingface_hub import notebook_login

# %%
notebook_login()

# %%
import pandas as pd

tsv_file_path = 'data/en_sentences.tsv'

df = pd.read_csv(tsv_file_path, sep='\t', header=None, usecols=[2])

df.to_csv('data/data_sentence_output.csv', index=False)

# %%
import csv

replacement_words = {}
with open('data/words_noise_data_sample.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        replacement_words[row[0]] = row[1]

# %%
replacement_words
# Out:
# {'word': 'werd',
#  'oak': 'owk',
#  'sorrow': 'saarow',
#  'kilograms': 'kihlahgraemz',
#  'taxi': 'taeksiy',
#  'beth': 'behth',
#  'fond': 'faand',
#  'division': 'dihvihzhahn',
#  'potential': 'pahtehnshahl',
#  'olympics': 'owlihmpihks',
#  'broker': 'browker',
#  'objects': 'aabjhehkts',
#  'surly': 'serliy',
#  'sucker': 'sahker',
#  'admitted': 'ahdmihtahd',
#  'quietly': 'kwayahtliy',
#  'overtaken': 'owverteykahn',
#  'rubbing': 'rahbihng',
#  'kissing': 'kihsihng',
#  'fatter': 'faeter',
#  'pretty': 'prihtiy',
#  'libya': 'lihbiyah',
#  'faces': 'feysahz',
#  'hyperinflation': 'hhayperihnfleyshahn',
#  'unlike': 'ahnlayk',
#  'attractions': 'ahtraekshahnz',
#  'transvestites': 'traenzvehstayts',
#  'pour': 'paor',
#  'biro': 'bihrow',
#  'jane': 'jheyn',
#  'dismissal': 'dihsmihsahl',
#  'courageous': 'kereyjhahs',
#  'roots': 'ruwts',
#  'estate': 'ihsteyt',
#  'squirrels': 'skwerahlz',
#  'licenses': 'laysahnsihz',
#  'astray': 'ahstrey',
#  'disco': 'dihskow',
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/jinda/Desktop/torgo/torgo_inference/Machine Translation/translation-bart-noise-word.ipynb Cell 7 line 5
#       <a href='vscode-notebook-cell:/home/jinda/Desktop/torgo/torgo_inference/Machine%20Translation/translation-bart-noise-word.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> import re
#       <a href='vscode-notebook-cell:/home/jinda/Desktop/torgo/torgo_inference/Machine%20Translation/translation-bart-noise-word.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> # Read the data_sentence_output.csv file
# ----> <a href='vscode-notebook-cell:/home/jinda/Desktop/torgo/torgo_inference/Machine%20Translation/translation-bart-noise-word.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> sentence_df = pd.read_csv('data_sentence_output.csv', header=None, names=['Sentence'])
# ...
